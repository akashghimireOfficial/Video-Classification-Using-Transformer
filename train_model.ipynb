# %%
from vvit_build_model import *

# %%
vvit_model=create_vivit_classifier()
# Out:
# 2022-03-19 04:12:08.139535: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-19 04:12:08.187059: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-19 04:12:08.187384: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-19 04:12:08.188809: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# ...

# %%
vvit_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 64, 64, 64,  0           []
#                                  3)]
#
#  tubelet_embedding (TubeletEmbe  (None, 512, 128)    196736      ['input_1[0][0]']
#  dding)
#
#  positional_encoder (Positional  (None, 512, 128)    65536       ['tubelet_embedding[0][0]']
#  Encoder)
#
#  layer_normalization (LayerNorm  (None, 512, 128)    256         ['positional_encoder[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 512, 128)    66048       ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  add (Add)                      (None, 512, 128)     0           ['multi_head_attention[0][0]',
# ...

# %%
checkpoint=tf.keras.callbacks.ModelCheckpoint('vvit_saved_model',monitor='val_acc',save_weights_only=True,save_best_only=False,
                                             verbose=1)

# %%
history=vvit_model.fit(x=X_train,y=y_train,validation_split=0.2,callbacks=[checkpoint],shuffle=1,epochs=60,batch_size=8)
# Out:
# Epoch 1/60
# 2022-03-19 04:14:23.880655: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8300
# 2022-03-19 04:14:25.823062: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# ...
# 32/32 [==============================] - 20s 191ms/step - loss: 1.7540 - accuracy: 0.3255 - val_loss: 1.3318 - val_accuracy: 0.2656
# Epoch 2/60
# ...
# 32/32 [==============================] - 5s 142ms/step - loss: 1.3561 - accuracy: 0.3137 - val_loss: 1.2780 - val_accuracy: 0.4531
# Epoch 3/60
# ...
# 32/32 [==============================] - 5s 142ms/step - loss: 1.4085 - accuracy: 0.3569 - val_loss: 1.1957 - val_accuracy: 0.5000
# Epoch 4/60
# ...
# 32/32 [==============================] - 5s 156ms/step - loss: 1.2999 - accuracy: 0.3686 - val_loss: 1.1497 - val_accuracy: 0.4844
# Epoch 5/60
# ...
